# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gymnasium as gym
from collections import deque

# --- Hyperparameters ---
LEARNING_RATE = 3e-4
GAMMA = 0.99  # Discount factor for future rewards
GAE_LAMBDA = 0.95  # Lambda for Generalized Advantage Estimation (GAE)
PPO_EPOCHS = 10  # How many times to iterate over the collected batch
CLIP_EPSILON = 0.2  # Clipping parameter for PPO loss
VALUE_COEF = 0.5  # Coefficient for the value function loss
ENTROPY_COEF = 0.01  # Coefficient for the entropy term (encourages exploration)
BATCH_SIZE = 64
TIMESTEPS_PER_BATCH = 2048  # How many environment steps to collect before a PPO update
MAX_TIMESTEPS = 1000000

# --- 1. Actor-Critic Network Architecture ---
class ActorCritic(nn.Module):
    """
    A single neural network that outputs both the policy (Actor)
    and the value function (Critic).
    """
    def __init__(self, obs_dim, action_dim):
        super(ActorCritic, self).__init__()

        # Shared Layer
        self.shared_layer = nn.Sequential(
            nn.Linear(obs_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )

        # Actor Head (Policy - outputs probabilities for actions)
        self.actor_head = nn.Sequential(
            nn.Linear(64, action_dim),
            nn.Softmax(dim=-1) # Softmax converts logits to probabilities
        )

        # Critic Head (Value - outputs V(s), the expected return from state s)
        self.critic_head = nn.Sequential(
            nn.Linear(64, 1) # Outputs a single scalar value
        )

    def forward(self, x):
        shared_output = self.shared_layer(x)
        action_probs = self.actor_head(shared_output)
        value = self.critic_head(shared_output)
        return action_probs, value

# --- 2. PPO Agent Class ---
class PPOAgent:
    def __init__(self, env):
        self.env = env
        self.obs_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n

        # Initialize the Actor-Critic model and optimizer
        self.model = ActorCritic(self.obs_dim, self.action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=LEARNING_RATE)

        # Store data for the training batch
        self.batch_data = {
            'states': [], 'actions': [], 'rewards': [],
            'log_probs': [], 'dones': [], 'values': []
        }

    def select_action(self, state):
        """Selects an action based on the current policy."""
        # Convert NumPy state array to PyTorch tensor
        state_tensor = torch.from_numpy(state).float().unsqueeze(0)

        # Get action probabilities and state value from the model
        with torch.no_grad():
            action_probs, value = self.model(state_tensor)

        # Sample an action from the categorical distribution defined by action_probs
        action_dist = torch.distributions.Categorical(action_probs)
        action = action_dist.sample()

        # Calculate the log probability of the sampled action
        log_prob = action_dist.log_prob(action)

        # Return action (as int), log_prob (scalar), and value (scalar)
        return action.item(), log_prob.item(), value.item()

    def store_transition(self, state, action, reward, log_prob, done, value):
        """Stores a step's experience for later batch training."""
        self.batch_data['states'].append(state)
        self.batch_data['actions'].append(action)
        self.batch_data['rewards'].append(reward)
        self.batch_data['log_probs'].append(log_prob)
        self.batch_data['dones'].append(done)
        self.batch_data['values'].append(value)

    def _compute_advantages_and_returns(self, next_value):
        """
        Computes the General Advantage Estimate (GAE) and the
        target returns for the value function loss.
        """
        rewards = np.array(self.batch_data['rewards'])
        values = np.array(self.batch_data['values'])
        dones = np.array(self.batch_data['dones'])

        # Append the value of the final state (or 0 if terminal)
        # Note: In CartPole, the episode ends when 'done' is True.
        # However, PPO needs the value of the *next* state, even if it's the last.
        # We handle this by setting the final advantage/return target correctly.

        # Compute discounted returns (targets for the critic)
        returns = np.zeros_like(rewards)
        # Compute advantages (used to scale the actor's policy updates)
        advantages = np.zeros_like(rewards)

        last_gae_lambda = 0

        # Iterate backwards through the trajectory to compute GAE and returns
        for t in reversed(range(len(rewards))):
            if t == len(rewards) - 1:
                # Delta at the last step uses the value of the next state (or 0 if done)
                next_non_terminal = 1.0 - dones[t]
                delta = rewards[t] + GAMMA * next_value * next_non_terminal - values[t]
                returns[t] = rewards[t] + GAMMA * next_value * next_non_terminal
            else:
                next_non_terminal = 1.0 - dones[t+1]
                # Delta is the temporal difference error
                delta = rewards[t] + GAMMA * values[t+1] * next_non_terminal - values[t]
                returns[t] = rewards[t] + GAMMA * returns[t+1] * next_non_terminal # Simple discounted return

            # GAE is an exponentially weighted average of the TD errors
            advantages[t] = last_gae_lambda = delta + GAMMA * GAE_LAMBDA * next_non_terminal * last_gae_lambda

        # Advantages are normalized to stabilize training
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        return advantages, returns

    def learn(self, next_state):
        """
        Performs the PPO update using the collected batch data.
        """
        print("--- PPO Update Cycle Started ---")

        # Get the value of the final state in the batch
        with torch.no_grad():
            next_state_tensor = torch.from_numpy(next_state).float().unsqueeze(0)
            _, next_value = self.model(next_state_tensor)
            next_value = next_value.item()

        # 1. Calculate Advantages (GAE) and Returns (Targets)
        advantages, returns = self._compute_advantages_and_returns(next_value)

        # 2. Convert collected data to Tensors
        states = torch.tensor(np.array(self.batch_data['states']), dtype=torch.float)
        actions = torch.tensor(np.array(self.batch_data['actions']), dtype=torch.long)
        old_log_probs = torch.tensor(np.array(self.batch_data['log_probs']), dtype=torch.float)
        returns = torch.tensor(returns, dtype=torch.float).unsqueeze(1)
        advantages = torch.tensor(advantages, dtype=torch.float).unsqueeze(1)

        # 3. PPO Epochs
        data_size = len(states)
        indices = np.arange(data_size)

        for _ in range(PPO_EPOCHS):
            # Shuffle indices for stochastic gradient descent
            np.random.shuffle(indices)

            # Iterate through mini-batches
            for start in range(0, data_size, BATCH_SIZE):
                end = start + BATCH_SIZE
                batch_indices = indices[start:end]

                # Extract mini-batch
                b_states = states[batch_indices]
                b_actions = actions[batch_indices]
                b_old_log_probs = old_log_probs[batch_indices].unsqueeze(1)
                b_returns = returns[batch_indices]
                b_advantages = advantages[batch_indices]

                # Get new action probabilities and state values
                action_probs, new_values = self.model(b_states)

                # Calculate new log probabilities and entropy
                dist = torch.distributions.Categorical(action_probs)
                new_log_probs = dist.log_prob(b_actions).unsqueeze(1)
                entropy = dist.entropy().mean()

                # --- PPO Loss Calculation ---

                # Calculate the probability ratio (r_t)
                ratio = torch.exp(new_log_probs - b_old_log_probs)

                # 1. Actor Loss (Policy Loss)
                # Unclipped loss
                surr1 = ratio * b_advantages
                # Clipped loss
                surr2 = torch.clamp(ratio, 1.0 - CLIP_EPSILON, 1.0 + CLIP_EPSILON) * b_advantages
                # Policy loss takes the minimum of the two to penalize large policy updates
                policy_loss = -torch.min(surr1, surr2).mean()

                # 2. Critic Loss (Value Loss)
                # This is the Mean Squared Error between the predicted value and the GAE returns
                value_loss = (new_values - b_returns).pow(2).mean()

                # 3. Total Loss
                # The entropy term is added to encourage exploration and prevent premature convergence.
                total_loss = policy_loss + VALUE_COEF * value_loss - ENTROPY_COEF * entropy

                # Optimization step
                self.optimizer.zero_grad()
                total_loss.backward()
                nn.utils.clip_grad_norm_(self.model.parameters(), 0.5) # Gradient clipping for stability
                self.optimizer.step()

        # 4. Clear the batch data after the update
        self.batch_data = {
            'states': [], 'actions': [], 'rewards': [],
            'log_probs': [], 'dones': [], 'values': []
        }

        print("--- PPO Update Cycle Finished ---")


# --- 3. Main Training Loop ---
def main():
    # Use a standard Gym environment
    env = gym.make("CartPole-v1")
    agent = PPOAgent(env)

    # Track episode scores for monitoring
    scores = deque(maxlen=100)

    total_timesteps = 0
    i_episode = 0

    print(f"Starting PPO training on CartPole-v1...")

    while total_timesteps < MAX_TIMESTEPS:
        state, _ = env.reset()
        episode_reward = 0
        i_episode += 1

        for t in range(TIMESTEPS_PER_BATCH):
            # 1. Interact with the environment
            action, log_prob, value = agent.select_action(state)

            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            # 2. Store the transition
            agent.store_transition(state, action, reward, log_prob, done, value)

            state = next_state
            episode_reward += reward
            total_timesteps += 1

            # If episode ends, reset the environment and record the score
            if done:
                scores.append(episode_reward)
                mean_score = np.mean(scores)

                print(f"Episode {i_episode:5d} | Timestep {total_timesteps:7d} | Score: {episode_reward:5.1f} | 100-Avg: {mean_score:5.2f}")

                # Check for "solving" the environment (CartPole-v1 is solved when avg score >= 195 over 100 episodes)
                if mean_score >= 195.0:
                    print("\n*** ENVIRONMENT SOLVED! Average score >= 195.0 over 100 episodes. ***\n")
                    # Break the inner loop to trigger the PPO update one last time
                    break

                # Reset environment for the next episode
                state, _ = env.reset()
                episode_reward = 0

        # 3. Perform the PPO Update after collecting the batch of data
        agent.learn(state) # state is the starting state of the next interaction batch

    env.close()

if __name__ == '__main__':
    # Set the seed for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)

    # Ensure all collected data is used before training
    # The batch size is set large enough to collect a full trajectory
    main()
# Out:
# Starting PPO training on CartPole-v1...
# Episode     1 | Timestep      20 | Score:  20.0 | 100-Avg: 20.00
# Episode     1 | Timestep      34 | Score:  14.0 | 100-Avg: 17.00
# Episode     1 | Timestep      50 | Score:  16.0 | 100-Avg: 16.67
# Episode     1 | Timestep      86 | Score:  36.0 | 100-Avg: 21.50
# Episode     1 | Timestep     133 | Score:  47.0 | 100-Avg: 26.60
# Episode     1 | Timestep     147 | Score:  14.0 | 100-Avg: 24.50
# Episode     1 | Timestep     167 | Score:  20.0 | 100-Avg: 23.86
# Episode     1 | Timestep     180 | Score:  13.0 | 100-Avg: 22.50
# Episode     1 | Timestep     229 | Score:  49.0 | 100-Avg: 25.44
# Episode     1 | Timestep     241 | Score:  12.0 | 100-Avg: 24.10
# Episode     1 | Timestep     267 | Score:  26.0 | 100-Avg: 24.27
# Episode     1 | Timestep     287 | Score:  20.0 | 100-Avg: 23.92
# Episode     1 | Timestep     299 | Score:  12.0 | 100-Avg: 23.00
# Episode     1 | Timestep     336 | Score:  37.0 | 100-Avg: 24.00
# Episode     1 | Timestep     376 | Score:  40.0 | 100-Avg: 25.07
# Episode     1 | Timestep     419 | Score:  43.0 | 100-Avg: 26.19
# Episode     1 | Timestep     443 | Score:  24.0 | 100-Avg: 26.06
# Episode     1 | Timestep     461 | Score:  18.0 | 100-Avg: 25.61
# Episode     1 | Timestep     477 | Score:  16.0 | 100-Avg: 25.11
# Episode     1 | Timestep     506 | Score:  29.0 | 100-Avg: 25.30
# Episode     1 | Timestep     518 | Score:  12.0 | 100-Avg: 24.67
# Episode     1 | Timestep     538 | Score:  20.0 | 100-Avg: 24.45
# Episode     1 | Timestep     579 | Score:  41.0 | 100-Avg: 25.17
# Episode     1 | Timestep     589 | Score:  10.0 | 100-Avg: 24.54
# Episode     1 | Timestep     615 | Score:  26.0 | 100-Avg: 24.60
# Episode     1 | Timestep     628 | Score:  13.0 | 100-Avg: 24.15
# Episode     1 | Timestep     642 | Score:  14.0 | 100-Avg: 23.78
# Episode     1 | Timestep     666 | Score:  24.0 | 100-Avg: 23.79
# Episode     1 | Timestep     690 | Score:  24.0 | 100-Avg: 23.79
# Episode     1 | Timestep     699 | Score:   9.0 | 100-Avg: 23.30
# Episode     1 | Timestep     714 | Score:  15.0 | 100-Avg: 23.03
# Episode     1 | Timestep     734 | Score:  20.0 | 100-Avg: 22.94
# Episode     1 | Timestep     760 | Score:  26.0 | 100-Avg: 23.03
# Episode     1 | Timestep     774 | Score:  14.0 | 100-Avg: 22.76
# Episode     1 | Timestep     797 | Score:  23.0 | 100-Avg: 22.77
# Episode     1 | Timestep     820 | Score:  23.0 | 100-Avg: 22.78
# Episode     1 | Timestep     831 | Score:  11.0 | 100-Avg: 22.46
# Episode     1 | Timestep     854 | Score:  23.0 | 100-Avg: 22.47
# Episode     1 | Timestep     867 | Score:  13.0 | 100-Avg: 22.23
# Episode     1 | Timestep     880 | Score:  13.0 | 100-Avg: 22.00
# Episode     1 | Timestep     894 | Score:  14.0 | 100-Avg: 21.80
# Episode     1 | Timestep     920 | Score:  26.0 | 100-Avg: 21.90
# Episode     1 | Timestep     939 | Score:  19.0 | 100-Avg: 21.84
# Episode     1 | Timestep     963 | Score:  24.0 | 100-Avg: 21.89
# Episode     1 | Timestep     978 | Score:  15.0 | 100-Avg: 21.73
# Episode     1 | Timestep    1001 | Score:  23.0 | 100-Avg: 21.76
# Episode     1 | Timestep    1020 | Score:  19.0 | 100-Avg: 21.70
# Episode     1 | Timestep    1031 | Score:  11.0 | 100-Avg: 21.48
# Episode     1 | Timestep    1051 | Score:  20.0 | 100-Avg: 21.45
# Episode     1 | Timestep    1062 | Score:  11.0 | 100-Avg: 21.24
# Episode     1 | Timestep    1074 | Score:  12.0 | 100-Avg: 21.06
# Episode     1 | Timestep    1092 | Score:  18.0 | 100-Avg: 21.00
# Episode     1 | Timestep    1129 | Score:  37.0 | 100-Avg: 21.30
# Episode     1 | Timestep    1175 | Score:  46.0 | 100-Avg: 21.76
# Episode     1 | Timestep    1200 | Score:  25.0 | 100-Avg: 21.82
# Episode     1 | Timestep    1211 | Score:  11.0 | 100-Avg: 21.62
# Episode     1 | Timestep    1228 | Score:  17.0 | 100-Avg: 21.54
# Episode     1 | Timestep    1240 | Score:  12.0 | 100-Avg: 21.38
# Episode     1 | Timestep    1259 | Score:  19.0 | 100-Avg: 21.34
# Episode     1 | Timestep    1273 | Score:  14.0 | 100-Avg: 21.22
# Episode     1 | Timestep    1290 | Score:  17.0 | 100-Avg: 21.15
# Episode     1 | Timestep    1310 | Score:  20.0 | 100-Avg: 21.13
# Episode     1 | Timestep    1338 | Score:  28.0 | 100-Avg: 21.24
# Episode     1 | Timestep    1354 | Score:  16.0 | 100-Avg: 21.16
# Episode     1 | Timestep    1371 | Score:  17.0 | 100-Avg: 21.09
# Episode     1 | Timestep    1420 | Score:  49.0 | 100-Avg: 21.52
# Episode     1 | Timestep    1457 | Score:  37.0 | 100-Avg: 21.75
# Episode     1 | Timestep    1483 | Score:  26.0 | 100-Avg: 21.81
# Episode     1 | Timestep    1507 | Score:  24.0 | 100-Avg: 21.84
# Episode     1 | Timestep    1533 | Score:  26.0 | 100-Avg: 21.90
# Episode     1 | Timestep    1551 | Score:  18.0 | 100-Avg: 21.85
# Episode     1 | Timestep    1566 | Score:  15.0 | 100-Avg: 21.75
# Episode     1 | Timestep    1581 | Score:  15.0 | 100-Avg: 21.66
# Episode     1 | Timestep    1616 | Score:  35.0 | 100-Avg: 21.84
# Episode     1 | Timestep    1660 | Score:  44.0 | 100-Avg: 22.13
# Episode     1 | Timestep    1673 | Score:  13.0 | 100-Avg: 22.01
# Episode     1 | Timestep    1688 | Score:  15.0 | 100-Avg: 21.92
# Episode     1 | Timestep    1716 | Score:  28.0 | 100-Avg: 22.00
# Episode     1 | Timestep    1744 | Score:  28.0 | 100-Avg: 22.08
# Episode     1 | Timestep    1783 | Score:  39.0 | 100-Avg: 22.29
# Episode     1 | Timestep    1797 | Score:  14.0 | 100-Avg: 22.19
# Episode     1 | Timestep    1823 | Score:  26.0 | 100-Avg: 22.23
# Episode     1 | Timestep    1837 | Score:  14.0 | 100-Avg: 22.13
# Episode     1 | Timestep    1938 | Score: 101.0 | 100-Avg: 23.07
# Episode     1 | Timestep    1973 | Score:  35.0 | 100-Avg: 23.21
# Episode     1 | Timestep    2003 | Score:  30.0 | 100-Avg: 23.29
# Episode     1 | Timestep    2030 | Score:  27.0 | 100-Avg: 23.33
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     2 | Timestep    2058 | Score:  10.0 | 100-Avg: 23.18
# Episode     2 | Timestep    2069 | Score:  11.0 | 100-Avg: 23.04
# Episode     2 | Timestep    2088 | Score:  19.0 | 100-Avg: 23.00
# Episode     2 | Timestep    2109 | Score:  21.0 | 100-Avg: 22.98
# Episode     2 | Timestep    2122 | Score:  13.0 | 100-Avg: 22.87
# Episode     2 | Timestep    2165 | Score:  43.0 | 100-Avg: 23.09
# Episode     2 | Timestep    2186 | Score:  21.0 | 100-Avg: 23.06
# Episode     2 | Timestep    2199 | Score:  13.0 | 100-Avg: 22.96
# Episode     2 | Timestep    2208 | Score:   9.0 | 100-Avg: 22.81
# Episode     2 | Timestep    2228 | Score:  20.0 | 100-Avg: 22.78
# Episode     2 | Timestep    2274 | Score:  46.0 | 100-Avg: 23.02
# Episode     2 | Timestep    2300 | Score:  26.0 | 100-Avg: 23.05
# Episode     2 | Timestep    2332 | Score:  32.0 | 100-Avg: 23.14
# Episode     2 | Timestep    2357 | Score:  25.0 | 100-Avg: 23.19
# Episode     2 | Timestep    2397 | Score:  40.0 | 100-Avg: 23.45
# Episode     2 | Timestep    2477 | Score:  80.0 | 100-Avg: 24.09
# Episode     2 | Timestep    2491 | Score:  14.0 | 100-Avg: 23.87
# Episode     2 | Timestep    2517 | Score:  26.0 | 100-Avg: 23.66
# Episode     2 | Timestep    2537 | Score:  20.0 | 100-Avg: 23.72
# Episode     2 | Timestep    2563 | Score:  26.0 | 100-Avg: 23.78
# Episode     2 | Timestep    2588 | Score:  25.0 | 100-Avg: 23.90
# Episode     2 | Timestep    2703 | Score: 115.0 | 100-Avg: 24.56
# Episode     2 | Timestep    2715 | Score:  12.0 | 100-Avg: 24.56
# Episode     2 | Timestep    2735 | Score:  20.0 | 100-Avg: 24.50
# Episode     2 | Timestep    2753 | Score:  18.0 | 100-Avg: 24.48
# Episode     2 | Timestep    2768 | Score:  15.0 | 100-Avg: 24.51
# Episode     2 | Timestep    2799 | Score:  31.0 | 100-Avg: 24.45
# Episode     2 | Timestep    2825 | Score:  26.0 | 100-Avg: 24.31
# Episode     2 | Timestep    2838 | Score:  13.0 | 100-Avg: 24.01
# Episode     2 | Timestep    2853 | Score:  15.0 | 100-Avg: 23.92
# Episode     2 | Timestep    2872 | Score:  19.0 | 100-Avg: 23.93
# Episode     2 | Timestep    2900 | Score:  28.0 | 100-Avg: 24.05
# Episode     2 | Timestep    2955 | Score:  55.0 | 100-Avg: 24.31
# Episode     2 | Timestep    2970 | Score:  15.0 | 100-Avg: 24.34
# Episode     2 | Timestep    2986 | Score:  16.0 | 100-Avg: 24.30
# Episode     2 | Timestep    3003 | Score:  17.0 | 100-Avg: 24.06
# Episode     2 | Timestep    3023 | Score:  20.0 | 100-Avg: 24.16
# Episode     2 | Timestep    3064 | Score:  41.0 | 100-Avg: 24.31
# Episode     2 | Timestep    3086 | Score:  22.0 | 100-Avg: 24.40
# Episode     2 | Timestep    3113 | Score:  27.0 | 100-Avg: 24.53
# Episode     2 | Timestep    3139 | Score:  26.0 | 100-Avg: 24.55
# Episode     2 | Timestep    3218 | Score:  79.0 | 100-Avg: 25.10
# Episode     2 | Timestep    3239 | Score:  21.0 | 100-Avg: 25.22
# Episode     2 | Timestep    3278 | Score:  39.0 | 100-Avg: 25.46
# Episode     2 | Timestep    3292 | Score:  14.0 | 100-Avg: 25.40
# Episode     2 | Timestep    3352 | Score:  60.0 | 100-Avg: 25.74
# Episode     2 | Timestep    3404 | Score:  52.0 | 100-Avg: 26.12
# Episode     2 | Timestep    3447 | Score:  43.0 | 100-Avg: 26.32
# Episode     2 | Timestep    3469 | Score:  22.0 | 100-Avg: 26.31
# Episode     2 | Timestep    3500 | Score:  31.0 | 100-Avg: 26.51
# Episode     2 | Timestep    3514 | Score:  14.0 | 100-Avg: 26.42
# Episode     2 | Timestep    3527 | Score:  13.0 | 100-Avg: 26.42
# Episode     2 | Timestep    3540 | Score:  13.0 | 100-Avg: 26.42
# Episode     2 | Timestep    3551 | Score:  11.0 | 100-Avg: 26.39
# Episode     2 | Timestep    3589 | Score:  38.0 | 100-Avg: 26.51
# Episode     2 | Timestep    3647 | Score:  58.0 | 100-Avg: 26.90
# Episode     2 | Timestep    3675 | Score:  28.0 | 100-Avg: 26.94
# Episode     2 | Timestep    3691 | Score:  16.0 | 100-Avg: 26.95
# Episode     2 | Timestep    3713 | Score:  22.0 | 100-Avg: 26.94
# Episode     2 | Timestep    3726 | Score:  13.0 | 100-Avg: 26.88
# Episode     2 | Timestep    3779 | Score:  53.0 | 100-Avg: 27.30
# Episode     2 | Timestep    3799 | Score:  20.0 | 100-Avg: 27.30
# Episode     2 | Timestep    3812 | Score:  13.0 | 100-Avg: 27.32
# Episode     2 | Timestep    3842 | Score:  30.0 | 100-Avg: 27.50
# Episode     2 | Timestep    3856 | Score:  14.0 | 100-Avg: 27.46
# Episode     2 | Timestep    3886 | Score:  30.0 | 100-Avg: 27.39
# Episode     2 | Timestep    3898 | Score:  12.0 | 100-Avg: 27.05
# Episode     2 | Timestep    3932 | Score:  34.0 | 100-Avg: 27.14
# Episode     2 | Timestep    3994 | Score:  62.0 | 100-Avg: 27.65
# Episode     2 | Timestep    4007 | Score:  13.0 | 100-Avg: 27.61
# Episode     2 | Timestep    4018 | Score:  11.0 | 100-Avg: 27.60
# Episode     2 | Timestep    4035 | Score:  17.0 | 100-Avg: 27.58
# Episode     2 | Timestep    4046 | Score:  11.0 | 100-Avg: 27.55
# Episode     2 | Timestep    4063 | Score:  17.0 | 100-Avg: 27.55
# Episode     2 | Timestep    4091 | Score:  28.0 | 100-Avg: 27.63
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     3 | Timestep    4124 | Score:  28.0 | 100-Avg: 27.63
# Episode     3 | Timestep    4146 | Score:  22.0 | 100-Avg: 27.69
# Episode     3 | Timestep    4163 | Score:  17.0 | 100-Avg: 27.69
# Episode     3 | Timestep    4191 | Score:  28.0 | 100-Avg: 27.48
# Episode     3 | Timestep    4215 | Score:  24.0 | 100-Avg: 27.35
# Episode     3 | Timestep    4253 | Score:  38.0 | 100-Avg: 27.47
# Episode     3 | Timestep    4265 | Score:  12.0 | 100-Avg: 27.35
# Episode     3 | Timestep    4282 | Score:  17.0 | 100-Avg: 27.26
# Episode     3 | Timestep    4299 | Score:  17.0 | 100-Avg: 27.25
# Episode     3 | Timestep    4352 | Score:  53.0 | 100-Avg: 27.63
# Episode     3 | Timestep    4384 | Score:  32.0 | 100-Avg: 27.80
# Episode     3 | Timestep    4413 | Score:  29.0 | 100-Avg: 27.74
# Episode     3 | Timestep    4435 | Score:  22.0 | 100-Avg: 27.52
# Episode     3 | Timestep    4456 | Score:  21.0 | 100-Avg: 27.60
# Episode     3 | Timestep    4468 | Score:  12.0 | 100-Avg: 27.57
# Episode     3 | Timestep    4511 | Score:  43.0 | 100-Avg: 27.72
# Episode     3 | Timestep    4536 | Score:  25.0 | 100-Avg: 27.69
# Episode     3 | Timestep    4562 | Score:  26.0 | 100-Avg: 27.56
# Episode     3 | Timestep    4594 | Score:  32.0 | 100-Avg: 27.74
# Episode     3 | Timestep    4620 | Score:  26.0 | 100-Avg: 27.74
# Episode     3 | Timestep    4672 | Score:  52.0 | 100-Avg: 28.12
# Episode     3 | Timestep    4686 | Score:  14.0 | 100-Avg: 27.25
# Episode     3 | Timestep    4702 | Score:  16.0 | 100-Avg: 27.06
# Episode     3 | Timestep    4745 | Score:  43.0 | 100-Avg: 27.19
# Episode     3 | Timestep    4771 | Score:  26.0 | 100-Avg: 27.18
# Episode     3 | Timestep    4801 | Score:  30.0 | 100-Avg: 27.38
# Episode     3 | Timestep    4817 | Score:  16.0 | 100-Avg: 27.43
# Episode     3 | Timestep    4849 | Score:  32.0 | 100-Avg: 27.56
# Episode     3 | Timestep    4872 | Score:  23.0 | 100-Avg: 27.58
# Episode     3 | Timestep    4882 | Score:  10.0 | 100-Avg: 27.55
# Episode     3 | Timestep    4899 | Score:  17.0 | 100-Avg: 27.29
# Episode     3 | Timestep    4936 | Score:  37.0 | 100-Avg: 27.45
# Episode     3 | Timestep    4954 | Score:  18.0 | 100-Avg: 27.50
# Episode     3 | Timestep    4972 | Score:  18.0 | 100-Avg: 27.59
# Episode     3 | Timestep    4990 | Score:  18.0 | 100-Avg: 27.57
# Episode     3 | Timestep    5006 | Score:  16.0 | 100-Avg: 27.27
# Episode     3 | Timestep    5039 | Score:  33.0 | 100-Avg: 27.34
# Episode     3 | Timestep    5051 | Score:  12.0 | 100-Avg: 27.14
# Episode     3 | Timestep    5066 | Score:  15.0 | 100-Avg: 27.04
# Episode     3 | Timestep    5093 | Score:  27.0 | 100-Avg: 26.91
# Episode     3 | Timestep    5163 | Score:  70.0 | 100-Avg: 26.81
# Episode     3 | Timestep    5190 | Score:  27.0 | 100-Avg: 26.94
# Episode     3 | Timestep    5229 | Score:  39.0 | 100-Avg: 27.07
# Episode     3 | Timestep    5237 | Score:   8.0 | 100-Avg: 26.95
# Episode     3 | Timestep    5285 | Score:  48.0 | 100-Avg: 27.17
# Episode     3 | Timestep    5302 | Score:  17.0 | 100-Avg: 27.09
# Episode     3 | Timestep    5318 | Score:  16.0 | 100-Avg: 26.10
# Episode     3 | Timestep    5333 | Score:  15.0 | 100-Avg: 26.13
# Episode     3 | Timestep    5361 | Score:  28.0 | 100-Avg: 26.21
# Episode     3 | Timestep    5384 | Score:  23.0 | 100-Avg: 26.26
# Episode     3 | Timestep    5405 | Score:  21.0 | 100-Avg: 26.32
# Episode     3 | Timestep    5433 | Score:  28.0 | 100-Avg: 26.29
# Episode     3 | Timestep    5460 | Score:  27.0 | 100-Avg: 26.30
# Episode     3 | Timestep    5491 | Score:  31.0 | 100-Avg: 26.48
# Episode     3 | Timestep    5515 | Score:  24.0 | 100-Avg: 26.57
# Episode     3 | Timestep    5539 | Score:  24.0 | 100-Avg: 26.62
# Episode     3 | Timestep    5560 | Score:  21.0 | 100-Avg: 26.55
# Episode     3 | Timestep    5587 | Score:  27.0 | 100-Avg: 26.27
# Episode     3 | Timestep    5605 | Score:  18.0 | 100-Avg: 26.30
# Episode     3 | Timestep    5671 | Score:  66.0 | 100-Avg: 26.80
# Episode     3 | Timestep    5685 | Score:  14.0 | 100-Avg: 26.77
# Episode     3 | Timestep    5700 | Score:  15.0 | 100-Avg: 26.72
# Episode     3 | Timestep    5713 | Score:  13.0 | 100-Avg: 26.44
# Episode     3 | Timestep    5742 | Score:  29.0 | 100-Avg: 26.51
# Episode     3 | Timestep    5753 | Score:  11.0 | 100-Avg: 26.35
# Episode     3 | Timestep    5783 | Score:  30.0 | 100-Avg: 26.39
# Episode     3 | Timestep    5792 | Score:   9.0 | 100-Avg: 25.69
# Episode     3 | Timestep    5807 | Score:  15.0 | 100-Avg: 25.63
# Episode     3 | Timestep    5842 | Score:  35.0 | 100-Avg: 25.59
# Episode     3 | Timestep    5851 | Score:   9.0 | 100-Avg: 25.54
# Episode     3 | Timestep    5868 | Score:  17.0 | 100-Avg: 25.11
# Episode     3 | Timestep    5881 | Score:  13.0 | 100-Avg: 24.72
# Episode     3 | Timestep    5898 | Score:  17.0 | 100-Avg: 24.46
# Episode     3 | Timestep    5913 | Score:  15.0 | 100-Avg: 24.39
# Episode     3 | Timestep    5937 | Score:  24.0 | 100-Avg: 24.32
# Episode     3 | Timestep    5968 | Score:  31.0 | 100-Avg: 24.49
# Episode     3 | Timestep    5985 | Score:  17.0 | 100-Avg: 24.53
# Episode     3 | Timestep    6002 | Score:  17.0 | 100-Avg: 24.57
# Episode     3 | Timestep    6015 | Score:  13.0 | 100-Avg: 24.59
# Episode     3 | Timestep    6029 | Score:  14.0 | 100-Avg: 24.35
# Episode     3 | Timestep    6049 | Score:  20.0 | 100-Avg: 23.97
# Episode     3 | Timestep    6066 | Score:  17.0 | 100-Avg: 23.86
# Episode     3 | Timestep    6080 | Score:  14.0 | 100-Avg: 23.84
# Episode     3 | Timestep    6139 | Score:  59.0 | 100-Avg: 24.21
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     4 | Timestep    6166 | Score:  22.0 | 100-Avg: 24.30
# Episode     4 | Timestep    6194 | Score:  28.0 | 100-Avg: 24.05
# Episode     4 | Timestep    6214 | Score:  20.0 | 100-Avg: 24.05
# Episode     4 | Timestep    6229 | Score:  15.0 | 100-Avg: 24.07
# Episode     4 | Timestep    6248 | Score:  19.0 | 100-Avg: 23.96
# Episode     4 | Timestep    6269 | Score:  21.0 | 100-Avg: 24.03
# Episode     4 | Timestep    6294 | Score:  25.0 | 100-Avg: 23.98
# Episode     4 | Timestep    6326 | Score:  32.0 | 100-Avg: 24.18
# Episode     4 | Timestep    6355 | Score:  29.0 | 100-Avg: 24.13
# Episode     4 | Timestep    6402 | Score:  47.0 | 100-Avg: 23.98
# Episode     4 | Timestep    6523 | Score: 121.0 | 100-Avg: 25.06
# Episode     4 | Timestep    6550 | Score:  27.0 | 100-Avg: 25.22
# Episode     4 | Timestep    6592 | Score:  42.0 | 100-Avg: 25.47
# Episode     4 | Timestep    6624 | Score:  32.0 | 100-Avg: 25.68
# Episode     4 | Timestep    6637 | Score:  13.0 | 100-Avg: 25.64
# Episode     4 | Timestep    6668 | Score:  31.0 | 100-Avg: 25.67
# Episode     4 | Timestep    6712 | Score:  44.0 | 100-Avg: 25.83
# Episode     4 | Timestep    6735 | Score:  23.0 | 100-Avg: 25.84
# Episode     4 | Timestep    6785 | Score:  50.0 | 100-Avg: 26.17
# Episode     4 | Timestep    6803 | Score:  18.0 | 100-Avg: 26.07
# Episode     4 | Timestep    6829 | Score:  26.0 | 100-Avg: 26.09
# Episode     4 | Timestep    6852 | Score:  23.0 | 100-Avg: 25.94
# Episode     4 | Timestep    6872 | Score:  20.0 | 100-Avg: 26.02
# Episode     4 | Timestep    6899 | Score:  27.0 | 100-Avg: 26.12
# Episode     4 | Timestep    6925 | Score:  26.0 | 100-Avg: 26.21
# Episode     4 | Timestep    6940 | Score:  15.0 | 100-Avg: 25.83
# Episode     4 | Timestep    6974 | Score:  34.0 | 100-Avg: 25.85
# Episode     4 | Timestep    6992 | Score:  18.0 | 100-Avg: 25.74
# Episode     4 | Timestep    7046 | Score:  54.0 | 100-Avg: 26.06
# Episode     4 | Timestep    7073 | Score:  27.0 | 100-Avg: 26.12
# Episode     4 | Timestep    7095 | Score:  22.0 | 100-Avg: 26.22
# Episode     4 | Timestep    7113 | Score:  18.0 | 100-Avg: 25.97
# Episode     4 | Timestep    7125 | Score:  12.0 | 100-Avg: 25.84
# Episode     4 | Timestep    7160 | Score:  35.0 | 100-Avg: 25.93
# Episode     4 | Timestep    7187 | Score:  27.0 | 100-Avg: 25.88
# Episode     4 | Timestep    7213 | Score:  26.0 | 100-Avg: 25.88
# Episode     4 | Timestep    7226 | Score:  13.0 | 100-Avg: 25.49
# Episode     4 | Timestep    7280 | Score:  54.0 | 100-Avg: 25.89
# Episode     4 | Timestep    7308 | Score:  28.0 | 100-Avg: 26.01
# Episode     4 | Timestep    7330 | Score:  22.0 | 100-Avg: 25.80
# Episode     4 | Timestep    7348 | Score:  18.0 | 100-Avg: 25.72
# Episode     4 | Timestep    7398 | Score:  50.0 | 100-Avg: 25.92
# Episode     4 | Timestep    7417 | Score:  19.0 | 100-Avg: 25.95
# Episode     4 | Timestep    7448 | Score:  31.0 | 100-Avg: 25.94
# Episode     4 | Timestep    7501 | Score:  53.0 | 100-Avg: 26.24
# Episode     4 | Timestep    7522 | Score:  21.0 | 100-Avg: 26.35
# Episode     4 | Timestep    7557 | Score:  35.0 | 100-Avg: 26.53
# Episode     4 | Timestep    7597 | Score:  40.0 | 100-Avg: 26.56
# Episode     4 | Timestep    7608 | Score:  11.0 | 100-Avg: 26.49
# Episode     4 | Timestep    7637 | Score:  29.0 | 100-Avg: 26.60
# Episode     4 | Timestep    7657 | Score:  20.0 | 100-Avg: 26.62
# Episode     4 | Timestep    7703 | Score:  46.0 | 100-Avg: 26.92
# Episode     4 | Timestep    7725 | Score:  22.0 | 100-Avg: 26.81
# Episode     4 | Timestep    7790 | Score:  65.0 | 100-Avg: 27.34
# Episode     4 | Timestep    7812 | Score:  22.0 | 100-Avg: 27.41
# Episode     4 | Timestep    7865 | Score:  53.0 | 100-Avg: 27.67
# Episode     4 | Timestep    7889 | Score:  24.0 | 100-Avg: 27.21
# Episode     4 | Timestep    7913 | Score:  24.0 | 100-Avg: 27.18
# Episode     4 | Timestep    7952 | Score:  39.0 | 100-Avg: 27.18
# Episode     4 | Timestep    7995 | Score:  43.0 | 100-Avg: 27.53
# Episode     4 | Timestep    8012 | Score:  17.0 | 100-Avg: 27.22
# Episode     4 | Timestep    8021 | Score:   9.0 | 100-Avg: 27.14
# Episode     4 | Timestep    8051 | Score:  30.0 | 100-Avg: 27.28
# Episode     4 | Timestep    8071 | Score:  20.0 | 100-Avg: 27.33
# Episode     4 | Timestep    8092 | Score:  21.0 | 100-Avg: 27.26
# Episode     4 | Timestep    8120 | Score:  28.0 | 100-Avg: 27.31
# Episode     4 | Timestep    8167 | Score:  47.0 | 100-Avg: 27.57
# Episode     4 | Timestep    8180 | Score:  13.0 | 100-Avg: 27.42
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     5 | Timestep    8242 | Score:  50.0 | 100-Avg: 27.65
# Episode     5 | Timestep    8288 | Score:  46.0 | 100-Avg: 27.80
# Episode     5 | Timestep    8306 | Score:  18.0 | 100-Avg: 27.74
# Episode     5 | Timestep    8326 | Score:  20.0 | 100-Avg: 27.70
# Episode     5 | Timestep    8345 | Score:  19.0 | 100-Avg: 27.68
# Episode     5 | Timestep    8428 | Score:  83.0 | 100-Avg: 28.24
# Episode     5 | Timestep    8455 | Score:  27.0 | 100-Avg: 28.33
# Episode     5 | Timestep    8475 | Score:  20.0 | 100-Avg: 27.87
# Episode     5 | Timestep    8488 | Score:  13.0 | 100-Avg: 27.86
# Episode     5 | Timestep    8504 | Score:  16.0 | 100-Avg: 27.87
# Episode     5 | Timestep    8553 | Score:  49.0 | 100-Avg: 28.23
# Episode     5 | Timestep    8570 | Score:  17.0 | 100-Avg: 28.11
# Episode     5 | Timestep    8620 | Score:  50.0 | 100-Avg: 28.50
# Episode     5 | Timestep    8748 | Score: 128.0 | 100-Avg: 29.48
# Episode     5 | Timestep    8768 | Score:  20.0 | 100-Avg: 29.59
# Episode     5 | Timestep    8801 | Score:  33.0 | 100-Avg: 29.77
# Episode     5 | Timestep    8825 | Score:  24.0 | 100-Avg: 29.66
# Episode     5 | Timestep    8876 | Score:  51.0 | 100-Avg: 30.08
# Episode     5 | Timestep    8917 | Score:  41.0 | 100-Avg: 30.32
# Episode     5 | Timestep    8941 | Score:  24.0 | 100-Avg: 30.43
# Episode     5 | Timestep    8959 | Score:  18.0 | 100-Avg: 30.44
# Episode     5 | Timestep    8973 | Score:  14.0 | 100-Avg: 30.43
# Episode     5 | Timestep    8990 | Score:  17.0 | 100-Avg: 30.36
# Episode     5 | Timestep    9035 | Score:  45.0 | 100-Avg: 30.50
# Episode     5 | Timestep    9058 | Score:  23.0 | 100-Avg: 30.56
# Episode     5 | Timestep    9089 | Score:  31.0 | 100-Avg: 30.70
# Episode     5 | Timestep    9102 | Score:  13.0 | 100-Avg: 30.70
# Episode     5 | Timestep    9126 | Score:  24.0 | 100-Avg: 30.80
# Episode     5 | Timestep    9157 | Score:  31.0 | 100-Avg: 30.91
# Episode     5 | Timestep    9179 | Score:  22.0 | 100-Avg: 30.96
# Episode     5 | Timestep    9271 | Score:  92.0 | 100-Avg: 31.74
# Episode     5 | Timestep    9310 | Score:  39.0 | 100-Avg: 31.54
# Episode     5 | Timestep    9332 | Score:  22.0 | 100-Avg: 31.54
# Episode     5 | Timestep    9433 | Score: 101.0 | 100-Avg: 32.27
# Episode     5 | Timestep    9447 | Score:  14.0 | 100-Avg: 32.21
# Episode     5 | Timestep    9472 | Score:  25.0 | 100-Avg: 32.31
# Episode     5 | Timestep    9489 | Score:  17.0 | 100-Avg: 32.29
# Episode     5 | Timestep    9500 | Score:  11.0 | 100-Avg: 32.19
# Episode     5 | Timestep    9573 | Score:  73.0 | 100-Avg: 32.67
# Episode     5 | Timestep    9639 | Score:  66.0 | 100-Avg: 33.01
# Episode     5 | Timestep    9671 | Score:  32.0 | 100-Avg: 33.04
# Episode     5 | Timestep    9708 | Score:  37.0 | 100-Avg: 32.94
# Episode     5 | Timestep    9725 | Score:  17.0 | 100-Avg: 31.90
# Episode     5 | Timestep    9784 | Score:  59.0 | 100-Avg: 32.22
# Episode     5 | Timestep    9799 | Score:  15.0 | 100-Avg: 31.95
# Episode     5 | Timestep    9833 | Score:  34.0 | 100-Avg: 31.97
# Episode     5 | Timestep    9856 | Score:  23.0 | 100-Avg: 32.07
# Episode     5 | Timestep    9879 | Score:  23.0 | 100-Avg: 31.99
# Episode     5 | Timestep    9909 | Score:  30.0 | 100-Avg: 31.85
# Episode     5 | Timestep    9947 | Score:  38.0 | 100-Avg: 32.00
# Episode     5 | Timestep    9969 | Score:  22.0 | 100-Avg: 31.72
# Episode     5 | Timestep   10031 | Score:  62.0 | 100-Avg: 32.16
# Episode     5 | Timestep   10090 | Score:  59.0 | 100-Avg: 32.49
# Episode     5 | Timestep   10121 | Score:  31.0 | 100-Avg: 32.57
# Episode     5 | Timestep   10173 | Score:  52.0 | 100-Avg: 32.89
# Episode     5 | Timestep   10189 | Score:  16.0 | 100-Avg: 32.78
# Episode     5 | Timestep   10221 | Score:  32.0 | 100-Avg: 32.84
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     6 | Timestep   10312 | Score:  72.0 | 100-Avg: 33.41
# Episode     6 | Timestep   10359 | Score:  47.0 | 100-Avg: 33.54
# Episode     6 | Timestep   10385 | Score:  26.0 | 100-Avg: 33.62
# Episode     6 | Timestep   10485 | Score: 100.0 | 100-Avg: 34.08
# Episode     6 | Timestep   10501 | Score:  16.0 | 100-Avg: 33.97
# Episode     6 | Timestep   10514 | Score:  13.0 | 100-Avg: 33.88
# Episode     6 | Timestep   10569 | Score:  55.0 | 100-Avg: 34.25
# Episode     6 | Timestep   10607 | Score:  38.0 | 100-Avg: 34.51
# Episode     6 | Timestep   10679 | Score:  72.0 | 100-Avg: 34.88
# Episode     6 | Timestep   10777 | Score:  98.0 | 100-Avg: 35.59
# Episode     6 | Timestep   10851 | Score:  74.0 | 100-Avg: 36.07
# Episode     6 | Timestep   10884 | Score:  33.0 | 100-Avg: 36.27
# Episode     6 | Timestep   10902 | Score:  18.0 | 100-Avg: 35.91
# Episode     6 | Timestep   10933 | Score:  31.0 | 100-Avg: 35.94
# Episode     6 | Timestep   11084 | Score: 151.0 | 100-Avg: 37.23
# Episode     6 | Timestep   11156 | Score:  72.0 | 100-Avg: 37.77
# Episode     6 | Timestep   11189 | Score:  33.0 | 100-Avg: 37.60
# Episode     6 | Timestep   11243 | Score:  54.0 | 100-Avg: 37.95
# Episode     6 | Timestep   11382 | Score: 139.0 | 100-Avg: 39.03
# Episode     6 | Timestep   11403 | Score:  21.0 | 100-Avg: 38.71
# Episode     6 | Timestep   11439 | Score:  36.0 | 100-Avg: 38.86
# Episode     6 | Timestep   11480 | Score:  41.0 | 100-Avg: 38.92
# Episode     6 | Timestep   11539 | Score:  59.0 | 100-Avg: 39.11
# Episode     6 | Timestep   11610 | Score:  71.0 | 100-Avg: 39.71
# Episode     6 | Timestep   11652 | Score:  42.0 | 100-Avg: 39.84
# Episode     6 | Timestep   11735 | Score:  83.0 | 100-Avg: 40.47
# Episode     6 | Timestep   11772 | Score:  37.0 | 100-Avg: 40.38
# Episode     6 | Timestep   11808 | Score:  36.0 | 100-Avg: 40.52
# Episode     6 | Timestep   11839 | Score:  31.0 | 100-Avg: 40.18
# Episode     6 | Timestep   11869 | Score:  30.0 | 100-Avg: 40.26
# Episode     6 | Timestep   11894 | Score:  25.0 | 100-Avg: 39.98
# Episode     6 | Timestep   11915 | Score:  21.0 | 100-Avg: 39.95
# Episode     6 | Timestep   11935 | Score:  20.0 | 100-Avg: 39.91
# Episode     6 | Timestep   12030 | Score:  95.0 | 100-Avg: 40.47
# Episode     6 | Timestep   12102 | Score:  72.0 | 100-Avg: 40.76
# Episode     6 | Timestep   12134 | Score:  32.0 | 100-Avg: 40.91
# Episode     6 | Timestep   12160 | Score:  26.0 | 100-Avg: 41.08
# Episode     6 | Timestep   12185 | Score:  25.0 | 100-Avg: 41.03
# Episode     6 | Timestep   12216 | Score:  31.0 | 100-Avg: 41.14
# Episode     6 | Timestep   12274 | Score:  58.0 | 100-Avg: 41.51
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     7 | Timestep   12332 | Score:  44.0 | 100-Avg: 41.67
# Episode     7 | Timestep   12394 | Score:  62.0 | 100-Avg: 41.82
# Episode     7 | Timestep   12497 | Score: 103.0 | 100-Avg: 42.72
# Episode     7 | Timestep   12513 | Score:  16.0 | 100-Avg: 42.38
# Episode     7 | Timestep   12532 | Score:  19.0 | 100-Avg: 42.11
# Episode     7 | Timestep   12595 | Score:  63.0 | 100-Avg: 42.56
# Episode     7 | Timestep   12648 | Score:  53.0 | 100-Avg: 42.89
# Episode     7 | Timestep   12689 | Score:  41.0 | 100-Avg: 43.11
# Episode     7 | Timestep   12767 | Score:  78.0 | 100-Avg: 43.06
# Episode     7 | Timestep   12858 | Score:  91.0 | 100-Avg: 43.70
# Episode     7 | Timestep   12887 | Score:  29.0 | 100-Avg: 43.79
# Episode     7 | Timestep   13019 | Score: 132.0 | 100-Avg: 44.98
# Episode     7 | Timestep   13057 | Score:  38.0 | 100-Avg: 45.20
# Episode     7 | Timestep   13138 | Score:  81.0 | 100-Avg: 45.52
# Episode     7 | Timestep   13228 | Score:  90.0 | 100-Avg: 46.25
# Episode     7 | Timestep   13261 | Score:  33.0 | 100-Avg: 46.08
# Episode     7 | Timestep   13322 | Score:  61.0 | 100-Avg: 45.41
# Episode     7 | Timestep   13345 | Score:  23.0 | 100-Avg: 45.44
# Episode     7 | Timestep   13424 | Score:  79.0 | 100-Avg: 45.90
# Episode     7 | Timestep   13511 | Score:  87.0 | 100-Avg: 46.53
# Episode     7 | Timestep   13541 | Score:  30.0 | 100-Avg: 46.32
# Episode     7 | Timestep   13655 | Score: 114.0 | 100-Avg: 47.05
# Episode     7 | Timestep   13696 | Score:  41.0 | 100-Avg: 47.22
# Episode     7 | Timestep   13724 | Score:  28.0 | 100-Avg: 47.32
# Episode     7 | Timestep   13816 | Score:  92.0 | 100-Avg: 48.10
# Episode     7 | Timestep   13862 | Score:  46.0 | 100-Avg: 48.39
# Episode     7 | Timestep   13882 | Score:  20.0 | 100-Avg: 48.14
# Episode     7 | Timestep   14108 | Score: 226.0 | 100-Avg: 50.17
# Episode     7 | Timestep   14178 | Score:  70.0 | 100-Avg: 50.56
# Episode     7 | Timestep   14271 | Score:  93.0 | 100-Avg: 51.36
# Episode     7 | Timestep   14300 | Score:  29.0 | 100-Avg: 51.41
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     8 | Timestep   14506 | Score: 170.0 | 100-Avg: 52.80
# Episode     8 | Timestep   14642 | Score: 136.0 | 100-Avg: 53.94
# Episode     8 | Timestep   14781 | Score: 139.0 | 100-Avg: 54.41
# Episode     8 | Timestep   14992 | Score: 211.0 | 100-Avg: 56.13
# Episode     8 | Timestep   15037 | Score:  45.0 | 100-Avg: 56.36
# Episode     8 | Timestep   15244 | Score: 207.0 | 100-Avg: 57.42
# Episode     8 | Timestep   15363 | Score: 119.0 | 100-Avg: 58.47
# Episode     8 | Timestep   15542 | Score: 179.0 | 100-Avg: 60.01
# Episode     8 | Timestep   15633 | Score:  91.0 | 100-Avg: 60.75
# Episode     8 | Timestep   15887 | Score: 254.0 | 100-Avg: 63.18
# Episode     8 | Timestep   16080 | Score: 193.0 | 100-Avg: 64.38
# Episode     8 | Timestep   16229 | Score: 149.0 | 100-Avg: 65.21
# Episode     8 | Timestep   16267 | Score:  38.0 | 100-Avg: 65.27
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode     9 | Timestep   16403 | Score:  19.0 | 100-Avg: 65.09
# Episode     9 | Timestep   16439 | Score:  36.0 | 100-Avg: 65.28
# Episode     9 | Timestep   16492 | Score:  53.0 | 100-Avg: 65.22
# Episode     9 | Timestep   16565 | Score:  73.0 | 100-Avg: 65.80
# Episode     9 | Timestep   16721 | Score: 156.0 | 100-Avg: 67.02
# Episode     9 | Timestep   16742 | Score:  21.0 | 100-Avg: 67.00
# Episode     9 | Timestep   16762 | Score:  20.0 | 100-Avg: 66.97
# Episode     9 | Timestep   16933 | Score: 171.0 | 100-Avg: 68.38
# Episode     9 | Timestep   17128 | Score: 195.0 | 100-Avg: 69.95
# Episode     9 | Timestep   17251 | Score: 123.0 | 100-Avg: 70.96
# Episode     9 | Timestep   17386 | Score: 135.0 | 100-Avg: 71.69
# Episode     9 | Timestep   17399 | Score:  13.0 | 100-Avg: 71.23
# Episode     9 | Timestep   17608 | Score: 209.0 | 100-Avg: 73.01
# Episode     9 | Timestep   17630 | Score:  22.0 | 100-Avg: 72.71
# Episode     9 | Timestep   17656 | Score:  26.0 | 100-Avg: 72.81
# Episode     9 | Timestep   17738 | Score:  82.0 | 100-Avg: 73.31
# Episode     9 | Timestep   17854 | Score: 116.0 | 100-Avg: 73.75
# Episode     9 | Timestep   17952 | Score:  98.0 | 100-Avg: 74.26
# Episode     9 | Timestep   18012 | Score:  60.0 | 100-Avg: 74.60
# Episode     9 | Timestep   18117 | Score: 105.0 | 100-Avg: 74.65
# Episode     9 | Timestep   18136 | Score:  19.0 | 100-Avg: 74.68
# Episode     9 | Timestep   18207 | Score:  71.0 | 100-Avg: 75.26
# Episode     9 | Timestep   18219 | Score:  12.0 | 100-Avg: 74.83
# Episode     9 | Timestep   18296 | Score:  77.0 | 100-Avg: 75.22
# Episode     9 | Timestep   18324 | Score:  28.0 | 100-Avg: 74.78
# Episode     9 | Timestep   18341 | Score:  17.0 | 100-Avg: 73.97
# Episode     9 | Timestep   18378 | Score:  37.0 | 100-Avg: 73.60
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    10 | Timestep   18580 | Score: 148.0 | 100-Avg: 74.75
# Episode    10 | Timestep   18800 | Score: 220.0 | 100-Avg: 76.77
# Episode    10 | Timestep   18921 | Score: 121.0 | 100-Avg: 77.67
# Episode    10 | Timestep   19000 | Score:  79.0 | 100-Avg: 76.95
# Episode    10 | Timestep   19128 | Score: 128.0 | 100-Avg: 77.51
# Episode    10 | Timestep   19142 | Score:  14.0 | 100-Avg: 77.32
# Episode    10 | Timestep   19263 | Score: 121.0 | 100-Avg: 77.99
# Episode    10 | Timestep   19329 | Score:  66.0 | 100-Avg: 77.26
# Episode    10 | Timestep   19432 | Score: 103.0 | 100-Avg: 78.08
# Episode    10 | Timestep   19521 | Score:  89.0 | 100-Avg: 78.61
# Episode    10 | Timestep   19601 | Score:  80.0 | 100-Avg: 79.00
# Episode    10 | Timestep   19695 | Score:  94.0 | 100-Avg: 79.35
# Episode    10 | Timestep   19876 | Score: 181.0 | 100-Avg: 80.45
# Episode    10 | Timestep   20062 | Score: 186.0 | 100-Avg: 81.89
# Episode    10 | Timestep   20360 | Score: 298.0 | 100-Avg: 84.04
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    11 | Timestep   20792 | Score: 312.0 | 100-Avg: 86.79
# Episode    11 | Timestep   21078 | Score: 286.0 | 100-Avg: 89.29
# Episode    11 | Timestep   21154 | Score:  76.0 | 100-Avg: 89.74
# Episode    11 | Timestep   21478 | Score: 324.0 | 100-Avg: 92.68
# Episode    11 | Timestep   21493 | Score:  15.0 | 100-Avg: 92.58
# Episode    11 | Timestep   21750 | Score: 257.0 | 100-Avg: 94.94
# Episode    11 | Timestep   21937 | Score: 187.0 | 100-Avg: 96.61
# Episode    11 | Timestep   22001 | Score:  64.0 | 100-Avg: 96.30
# Episode    11 | Timestep   22224 | Score: 223.0 | 100-Avg: 97.81
# Episode    11 | Timestep   22444 | Score: 220.0 | 100-Avg: 99.69
# Episode    11 | Timestep   22523 | Score:  79.0 | 100-Avg: 100.22
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    12 | Timestep   22565 | Score:  37.0 | 100-Avg: 100.34
# Episode    12 | Timestep   22696 | Score: 131.0 | 100-Avg: 101.34
# Episode    12 | Timestep   22713 | Score:  17.0 | 100-Avg: 100.93
# Episode    12 | Timestep   22728 | Score:  15.0 | 100-Avg: 100.64
# Episode    12 | Timestep   22784 | Score:  56.0 | 100-Avg: 100.58
# Episode    12 | Timestep   22816 | Score:  32.0 | 100-Avg: 99.87
# Episode    12 | Timestep   22866 | Score:  50.0 | 100-Avg: 100.21
# Episode    12 | Timestep   22914 | Score:  48.0 | 100-Avg: 100.50
# Episode    12 | Timestep   23028 | Score: 114.0 | 100-Avg: 101.01
# Episode    12 | Timestep   23061 | Score:  33.0 | 100-Avg: 100.81
# Episode    12 | Timestep   23109 | Score:  48.0 | 100-Avg: 100.88
# Episode    12 | Timestep   23159 | Score:  50.0 | 100-Avg: 100.60
# Episode    12 | Timestep   23201 | Score:  42.0 | 100-Avg: 100.11
# Episode    12 | Timestep   23252 | Score:  51.0 | 100-Avg: 100.33
# Episode    12 | Timestep   23463 | Score: 211.0 | 100-Avg: 101.12
# Episode    12 | Timestep   23582 | Score: 119.0 | 100-Avg: 101.93
# Episode    12 | Timestep   23624 | Score:  42.0 | 100-Avg: 101.54
# Episode    12 | Timestep   23716 | Score:  92.0 | 100-Avg: 101.56
# Episode    12 | Timestep   23734 | Score:  18.0 | 100-Avg: 101.41
# Episode    12 | Timestep   23791 | Score:  57.0 | 100-Avg: 101.37
# Episode    12 | Timestep   23874 | Score:  83.0 | 100-Avg: 101.97
# Episode    12 | Timestep   23954 | Score:  80.0 | 100-Avg: 101.98
# Episode    12 | Timestep   23991 | Score:  37.0 | 100-Avg: 101.48
# Episode    12 | Timestep   24065 | Score:  74.0 | 100-Avg: 101.92
# Episode    12 | Timestep   24104 | Score:  39.0 | 100-Avg: 101.17
# Episode    12 | Timestep   24138 | Score:  34.0 | 100-Avg: 101.10
# Episode    12 | Timestep   24161 | Score:  23.0 | 100-Avg: 101.05
# Episode    12 | Timestep   24208 | Score:  47.0 | 100-Avg: 100.60
# Episode    12 | Timestep   24228 | Score:  20.0 | 100-Avg: 100.34
# Episode    12 | Timestep   24309 | Score:  81.0 | 100-Avg: 100.95
# Episode    12 | Timestep   24406 | Score:  97.0 | 100-Avg: 99.66
# Episode    12 | Timestep   24502 | Score:  96.0 | 100-Avg: 99.92
# Episode    12 | Timestep   24562 | Score:  60.0 | 100-Avg: 99.59
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    13 | Timestep   24759 | Score: 183.0 | 100-Avg: 101.13
# Episode    13 | Timestep   24815 | Score:  56.0 | 100-Avg: 99.99
# Episode    13 | Timestep   25152 | Score: 337.0 | 100-Avg: 102.00
# Episode    13 | Timestep   25239 | Score:  87.0 | 100-Avg: 101.48
# Episode    13 | Timestep   25509 | Score: 270.0 | 100-Avg: 102.07
# Episode    13 | Timestep   25559 | Score:  50.0 | 100-Avg: 102.12
# Episode    13 | Timestep   25681 | Score: 122.0 | 100-Avg: 101.27
# Episode    13 | Timestep   25987 | Score: 306.0 | 100-Avg: 103.14
# Episode    13 | Timestep   26054 | Score:  67.0 | 100-Avg: 102.02
# Episode    13 | Timestep   26090 | Score:  36.0 | 100-Avg: 101.47
# Episode    13 | Timestep   26190 | Score: 100.0 | 100-Avg: 99.93
# Episode    13 | Timestep   26313 | Score: 123.0 | 100-Avg: 99.23
# Episode    13 | Timestep   26405 | Score:  92.0 | 100-Avg: 98.66
# Episode    13 | Timestep   26531 | Score: 126.0 | 100-Avg: 99.54
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    14 | Timestep   26676 | Score:  52.0 | 100-Avg: 99.87
# Episode    14 | Timestep   26761 | Score:  85.0 | 100-Avg: 100.36
# Episode    14 | Timestep   26832 | Score:  71.0 | 100-Avg: 100.54
# Episode    14 | Timestep   27228 | Score: 396.0 | 100-Avg: 103.77
# Episode    14 | Timestep   27383 | Score: 155.0 | 100-Avg: 103.76
# Episode    14 | Timestep   27592 | Score: 209.0 | 100-Avg: 105.64
# Episode    14 | Timestep   27769 | Score: 177.0 | 100-Avg: 107.21
# Episode    14 | Timestep   27882 | Score: 113.0 | 100-Avg: 106.63
# Episode    14 | Timestep   27938 | Score:  56.0 | 100-Avg: 105.24
# Episode    14 | Timestep   28163 | Score: 225.0 | 100-Avg: 106.26
# Episode    14 | Timestep   28235 | Score:  72.0 | 100-Avg: 105.63
# Episode    14 | Timestep   28302 | Score:  67.0 | 100-Avg: 106.17
# Episode    14 | Timestep   28398 | Score:  96.0 | 100-Avg: 105.04
# Episode    14 | Timestep   28664 | Score: 266.0 | 100-Avg: 107.48
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    15 | Timestep   28704 | Score:  32.0 | 100-Avg: 107.54
# Episode    15 | Timestep   28736 | Score:  32.0 | 100-Avg: 107.04
# Episode    15 | Timestep   28793 | Score:  57.0 | 100-Avg: 106.45
# Episode    15 | Timestep   28846 | Score:  53.0 | 100-Avg: 106.00
# Episode    15 | Timestep   28907 | Score:  61.0 | 100-Avg: 106.01
# Episode    15 | Timestep   29078 | Score: 171.0 | 100-Avg: 106.67
# Episode    15 | Timestep   29147 | Score:  69.0 | 100-Avg: 107.17
# Episode    15 | Timestep   29443 | Score: 296.0 | 100-Avg: 109.42
# Episode    15 | Timestep   29684 | Score: 241.0 | 100-Avg: 111.71
# Episode    15 | Timestep   29760 | Score:  76.0 | 100-Avg: 111.70
# Episode    15 | Timestep   29995 | Score: 235.0 | 100-Avg: 113.77
# Episode    15 | Timestep   30067 | Score:  72.0 | 100-Avg: 114.32
# Episode    15 | Timestep   30402 | Score: 335.0 | 100-Avg: 117.30
# Episode    15 | Timestep   30514 | Score: 112.0 | 100-Avg: 116.94
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    16 | Timestep   30826 | Score: 106.0 | 100-Avg: 115.80
# Episode    16 | Timestep   30990 | Score: 164.0 | 100-Avg: 116.23
# Episode    16 | Timestep   31179 | Score: 189.0 | 100-Avg: 117.33
# Episode    16 | Timestep   31312 | Score: 133.0 | 100-Avg: 117.38
# Episode    16 | Timestep   31575 | Score: 263.0 | 100-Avg: 119.87
# Episode    16 | Timestep   31830 | Score: 255.0 | 100-Avg: 121.21
# Episode    16 | Timestep   31918 | Score:  88.0 | 100-Avg: 121.43
# Episode    16 | Timestep   32087 | Score: 169.0 | 100-Avg: 122.09
# Episode    16 | Timestep   32230 | Score: 143.0 | 100-Avg: 122.63
# Episode    16 | Timestep   32701 | Score: 471.0 | 100-Avg: 126.54
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    17 | Timestep   32801 | Score:  33.0 | 100-Avg: 125.93
# Episode    17 | Timestep   32915 | Score: 114.0 | 100-Avg: 125.26
# Episode    17 | Timestep   33022 | Score: 107.0 | 100-Avg: 124.47
# Episode    17 | Timestep   33073 | Score:  51.0 | 100-Avg: 122.00
# Episode    17 | Timestep   33109 | Score:  36.0 | 100-Avg: 119.24
# Episode    17 | Timestep   33228 | Score: 119.0 | 100-Avg: 117.57
# Episode    17 | Timestep   33417 | Score: 189.0 | 100-Avg: 118.70
# Episode    17 | Timestep   33714 | Score: 297.0 | 100-Avg: 118.43
# Episode    17 | Timestep   34084 | Score: 370.0 | 100-Avg: 121.98
# Episode    17 | Timestep   34461 | Score: 377.0 | 100-Avg: 123.18
# Episode    17 | Timestep   34621 | Score: 160.0 | 100-Avg: 122.91
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    18 | Timestep   34932 | Score: 116.0 | 100-Avg: 123.43
# Episode    18 | Timestep   34987 | Score:  55.0 | 100-Avg: 121.75
# Episode    18 | Timestep   35038 | Score:  51.0 | 100-Avg: 120.06
# Episode    18 | Timestep   35238 | Score: 200.0 | 100-Avg: 121.27
# Episode    18 | Timestep   35546 | Score: 308.0 | 100-Avg: 123.98
# Episode    18 | Timestep   35829 | Score: 283.0 | 100-Avg: 125.50
# Episode    18 | Timestep   36099 | Score: 270.0 | 100-Avg: 128.03
# Episode    18 | Timestep   36178 | Score:  79.0 | 100-Avg: 128.67
# Episode    18 | Timestep   36599 | Score: 421.0 | 100-Avg: 132.32
# Episode    18 | Timestep   36692 | Score:  93.0 | 100-Avg: 132.93
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    19 | Timestep   36931 | Score:  67.0 | 100-Avg: 133.10
# Episode    19 | Timestep   37117 | Score: 186.0 | 100-Avg: 134.48
# Episode    19 | Timestep   37240 | Score: 123.0 | 100-Avg: 134.57
# Episode    19 | Timestep   37441 | Score: 201.0 | 100-Avg: 136.25
# Episode    19 | Timestep   37591 | Score: 150.0 | 100-Avg: 137.27
# Episode    19 | Timestep   37645 | Score:  54.0 | 100-Avg: 137.31
# Episode    19 | Timestep   37679 | Score:  34.0 | 100-Avg: 137.23
# Episode    19 | Timestep   37787 | Score: 108.0 | 100-Avg: 137.80
# Episode    19 | Timestep   37800 | Score:  13.0 | 100-Avg: 135.82
# Episode    19 | Timestep   37838 | Score:  38.0 | 100-Avg: 135.01
# Episode    19 | Timestep   37912 | Score:  74.0 | 100-Avg: 135.33
# Episode    19 | Timestep   38231 | Score: 319.0 | 100-Avg: 137.60
# Episode    19 | Timestep   38267 | Score:  36.0 | 100-Avg: 137.78
# Episode    19 | Timestep   38321 | Score:  54.0 | 100-Avg: 137.75
# Episode    19 | Timestep   38373 | Score:  52.0 | 100-Avg: 137.44
# Episode    19 | Timestep   38698 | Score: 325.0 | 100-Avg: 139.89
# Episode    19 | Timestep   38782 | Score:  84.0 | 100-Avg: 140.36
# Episode    19 | Timestep   38834 | Score:  52.0 | 100-Avg: 140.14
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    20 | Timestep   39412 | Score: 500.0 | 100-Avg: 144.75
# Episode    20 | Timestep   39906 | Score: 494.0 | 100-Avg: 149.35
# Episode    20 | Timestep   39991 | Score:  85.0 | 100-Avg: 149.97
# Episode    20 | Timestep   40491 | Score: 500.0 | 100-Avg: 154.50
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    21 | Timestep   41014 | Score:  54.0 | 100-Avg: 154.84
# Episode    21 | Timestep   41198 | Score: 184.0 | 100-Avg: 155.87
# Episode    21 | Timestep   41215 | Score:  17.0 | 100-Avg: 155.07
# Episode    21 | Timestep   41236 | Score:  21.0 | 100-Avg: 154.32
# Episode    21 | Timestep   41248 | Score:  12.0 | 100-Avg: 153.84
# Episode    21 | Timestep   41272 | Score:  24.0 | 100-Avg: 152.25
# Episode    21 | Timestep   41442 | Score: 170.0 | 100-Avg: 153.39
# Episode    21 | Timestep   41456 | Score:  14.0 | 100-Avg: 150.16
# Episode    21 | Timestep   41492 | Score:  36.0 | 100-Avg: 149.65
# Episode    21 | Timestep   41531 | Score:  39.0 | 100-Avg: 147.34
# Episode    21 | Timestep   41586 | Score:  55.0 | 100-Avg: 147.39
# Episode    21 | Timestep   41637 | Score:  51.0 | 100-Avg: 146.68
# Episode    21 | Timestep   41679 | Score:  42.0 | 100-Avg: 144.04
# Episode    21 | Timestep   41696 | Score:  17.0 | 100-Avg: 143.54
# Episode    21 | Timestep   41709 | Score:  13.0 | 100-Avg: 143.31
# Episode    21 | Timestep   41770 | Score:  61.0 | 100-Avg: 142.92
# Episode    21 | Timestep   41821 | Score:  51.0 | 100-Avg: 142.20
# Episode    21 | Timestep   41876 | Score:  55.0 | 100-Avg: 141.83
# Episode    21 | Timestep   41893 | Score:  17.0 | 100-Avg: 140.74
# Episode    21 | Timestep   41951 | Score:  58.0 | 100-Avg: 140.80
# Episode    21 | Timestep   42010 | Score:  59.0 | 100-Avg: 140.54
# Episode    21 | Timestep   42055 | Score:  45.0 | 100-Avg: 140.28
# Episode    21 | Timestep   42104 | Score:  49.0 | 100-Avg: 136.81
# Episode    21 | Timestep   42162 | Score:  58.0 | 100-Avg: 135.84
# Episode    21 | Timestep   42235 | Score:  73.0 | 100-Avg: 134.48
# Episode    21 | Timestep   42271 | Score:  36.0 | 100-Avg: 133.07
# Episode    21 | Timestep   42376 | Score: 105.0 | 100-Avg: 132.99
# Episode    21 | Timestep   42405 | Score:  29.0 | 100-Avg: 132.72
# Episode    21 | Timestep   42456 | Score:  51.0 | 100-Avg: 130.98
# Episode    21 | Timestep   42484 | Score:  28.0 | 100-Avg: 130.54
# Episode    21 | Timestep   42600 | Score: 116.0 | 100-Avg: 131.03
# Episode    21 | Timestep   42662 | Score:  62.0 | 100-Avg: 130.69
# Episode    21 | Timestep   42675 | Score:  13.0 | 100-Avg: 128.16
# Episode    21 | Timestep   42698 | Score:  23.0 | 100-Avg: 128.07
# Episode    21 | Timestep   42712 | Score:  14.0 | 100-Avg: 127.89
# Episode    21 | Timestep   42729 | Score:  17.0 | 100-Avg: 127.49
# Episode    21 | Timestep   42979 | Score: 250.0 | 100-Avg: 129.46
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    22 | Timestep   43508 | Score: 500.0 | 100-Avg: 133.85
# Episode    22 | Timestep   43836 | Score: 328.0 | 100-Avg: 135.42
# Episode    22 | Timestep   44081 | Score: 245.0 | 100-Avg: 137.18
# Episode    22 | Timestep   44480 | Score: 399.0 | 100-Avg: 138.21
# Episode    22 | Timestep   44631 | Score: 151.0 | 100-Avg: 137.31
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    23 | Timestep   45088 | Score:  32.0 | 100-Avg: 136.87
# Episode    23 | Timestep   45104 | Score:  16.0 | 100-Avg: 134.68
# Episode    23 | Timestep   45163 | Score:  59.0 | 100-Avg: 134.55
# Episode    23 | Timestep   45289 | Score: 126.0 | 100-Avg: 132.46
# Episode    23 | Timestep   45372 | Score:  83.0 | 100-Avg: 132.17
# Episode    23 | Timestep   45527 | Score: 155.0 | 100-Avg: 132.66
# Episode    23 | Timestep   45575 | Score:  48.0 | 100-Avg: 131.50
# Episode    23 | Timestep   45738 | Score: 163.0 | 100-Avg: 131.24
# Episode    23 | Timestep   45805 | Score:  67.0 | 100-Avg: 130.58
# Episode    23 | Timestep   45881 | Score:  76.0 | 100-Avg: 128.71
# Episode    23 | Timestep   45931 | Score:  50.0 | 100-Avg: 126.66
# Episode    23 | Timestep   45980 | Score:  49.0 | 100-Avg: 126.27
# Episode    23 | Timestep   46155 | Score: 175.0 | 100-Avg: 126.33
# Episode    23 | Timestep   46355 | Score: 200.0 | 100-Avg: 126.90
# Episode    23 | Timestep   46382 | Score:  27.0 | 100-Avg: 122.46
# Episode    23 | Timestep   46654 | Score: 272.0 | 100-Avg: 124.85
# Episode    23 | Timestep   46822 | Score: 168.0 | 100-Avg: 125.39
# Episode    23 | Timestep   46893 | Score:  71.0 | 100-Avg: 125.03
# Episode    23 | Timestep   46945 | Score:  52.0 | 100-Avg: 125.04
# Episode    23 | Timestep   46992 | Score:  47.0 | 100-Avg: 125.15
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    24 | Timestep   47223 | Score: 119.0 | 100-Avg: 125.15
# Episode    24 | Timestep   47723 | Score: 500.0 | 100-Avg: 128.26
# Episode    24 | Timestep   47913 | Score: 190.0 | 100-Avg: 127.19
# Episode    24 | Timestep   48413 | Score: 500.0 | 100-Avg: 128.49
# Episode    24 | Timestep   48728 | Score: 315.0 | 100-Avg: 127.87
# Episode    24 | Timestep   48808 | Score:  80.0 | 100-Avg: 127.07
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    25 | Timestep   49201 | Score:  49.0 | 100-Avg: 126.40
# Episode    25 | Timestep   49533 | Score: 332.0 | 100-Avg: 129.17
# Episode    25 | Timestep   49852 | Score: 319.0 | 100-Avg: 131.85
# Episode    25 | Timestep   50240 | Score: 388.0 | 100-Avg: 133.73
# Episode    25 | Timestep   50313 | Score:  73.0 | 100-Avg: 131.38
# Episode    25 | Timestep   50362 | Score:  49.0 | 100-Avg: 129.04
# Episode    25 | Timestep   50412 | Score:  50.0 | 100-Avg: 126.84
# Episode    25 | Timestep   50601 | Score: 189.0 | 100-Avg: 127.94
# Episode    25 | Timestep   50728 | Score: 127.0 | 100-Avg: 125.00
# Episode    25 | Timestep   50989 | Score: 261.0 | 100-Avg: 126.68
# Episode    25 | Timestep   51048 | Score:  59.0 | 100-Avg: 126.60
# Episode    25 | Timestep   51123 | Score:  75.0 | 100-Avg: 125.49
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    26 | Timestep   51317 | Score: 117.0 | 100-Avg: 125.43
# Episode    26 | Timestep   51370 | Score:  53.0 | 100-Avg: 123.95
# Episode    26 | Timestep   51422 | Score:  52.0 | 100-Avg: 122.97
# Episode    26 | Timestep   51556 | Score: 134.0 | 100-Avg: 123.77
# Episode    26 | Timestep   51761 | Score: 205.0 | 100-Avg: 125.48
# Episode    26 | Timestep   51783 | Score:  22.0 | 100-Avg: 124.62
# Episode    26 | Timestep   52018 | Score: 235.0 | 100-Avg: 126.84
# Episode    26 | Timestep   52144 | Score: 126.0 | 100-Avg: 127.72
# Episode    26 | Timestep   52228 | Score:  84.0 | 100-Avg: 127.82
# Episode    26 | Timestep   52394 | Score: 166.0 | 100-Avg: 126.29
# Episode    26 | Timestep   52448 | Score:  54.0 | 100-Avg: 126.47
# Episode    26 | Timestep   52616 | Score: 168.0 | 100-Avg: 127.61
# Episode    26 | Timestep   52832 | Score: 216.0 | 100-Avg: 129.25
# Episode    26 | Timestep   53005 | Score: 173.0 | 100-Avg: 127.73
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    27 | Timestep   53393 | Score: 145.0 | 100-Avg: 128.34
# Episode    27 | Timestep   53550 | Score: 157.0 | 100-Avg: 129.39
# Episode    27 | Timestep   53588 | Score:  38.0 | 100-Avg: 124.77
# Episode    27 | Timestep   53751 | Score: 163.0 | 100-Avg: 121.46
# Episode    27 | Timestep   53911 | Score: 160.0 | 100-Avg: 122.21
# Episode    27 | Timestep   54088 | Score: 177.0 | 100-Avg: 118.98
# Episode    27 | Timestep   54258 | Score: 170.0 | 100-Avg: 120.14
# Episode    27 | Timestep   54424 | Score: 166.0 | 100-Avg: 119.96
# Episode    27 | Timestep   54600 | Score: 176.0 | 100-Avg: 121.55
# Episode    27 | Timestep   54777 | Score: 177.0 | 100-Avg: 123.11
# Episode    27 | Timestep   54999 | Score: 222.0 | 100-Avg: 125.21
# Episode    27 | Timestep   55201 | Score: 202.0 | 100-Avg: 126.99
# --- PPO Update Cycle Started ---
# --- PPO Update Cycle Finished ---
# Episode    28 | Timestep   55460 | Score: 164.0 | 100-Avg: 126.93
# Episode    28 | Timestep   55618 | Score: 158.0 | 100-Avg: 128.37
# Episode    28 | Timestep   55645 | Score:  27.0 | 100-Avg: 128.28
# Episode    28 | Timestep   55819 | Score: 174.0 | 100-Avg: 129.63
# Episode    28 | Timestep   55848 | Score:  29.0 | 100-Avg: 129.37
# Episode    28 | Timestep   55903 | Score:  55.0 | 100-Avg: 129.41
# Episode    28 | Timestep   55920 | Score:  17.0 | 100-Avg: 129.16
# Episode    28 | Timestep   56070 | Score: 150.0 | 100-Avg: 130.49
# Episode    28 | Timestep   56228 | Score: 158.0 | 100-Avg: 131.94
# Episode    28 | Timestep   56392 | Score: 164.0 | 100-Avg: 132.97
# Episode    28 | Timestep   56423 | Score:  31.0 | 100-Avg: 132.77
# Episode    28 | Timestep   56475 | Score:  52.0 | 100-Avg: 132.74
# Episode    28 | Timestep   56513 | Score:  38.0 | 100-Avg: 132.95
# Episode    28 | Timestep   56690 | Score: 177.0 | 100-Avg: 134.14
# Episode    28 | Timestep   56717 | Score:  27.0 | 100-Avg: 133.82
# Episode    28 | Timestep   56734 | Score:  17.0 | 100-Avg: 133.54
# Episode    28 | Timestep   56891 | Score: 157.0 | 100-Avg: 134.62
# Episode    28 | Timestep   57065 | Score: 174.0 | 100-Avg: 135.78
